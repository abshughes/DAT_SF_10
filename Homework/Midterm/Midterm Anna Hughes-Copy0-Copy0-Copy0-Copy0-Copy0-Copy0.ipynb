# %% [markdown]
# ###### Importing data and packages

# %%
import pandas as pd
import numpy as np
import string
import statsmodels.api as sm
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
import string
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
from sklearn.cross_validation import train_test_split

# %matplotlib inline
df=pd.read_csv('train.csv')
dfs=df.dropna()
print dfs.Survived.mean()
print df.Survived.mean()
# Out:
# 0.672131147541
# 0.383838383838

# %% [markdown]
# ###### Here is a number of functions I am going to use for data cleaning and feature creation. They don't really work independently and require to be applied in certain order. But this is still better solution than to write the code all over again for a test sample.

# %%
# Function for creating the column 'Title' and filling it in with the word from 'Name' field
def title_fill(df) :
    for i in df.index: 
        df.ix[i, 'Title']=df.ix[i, 'Name'].partition('.')[0]
        df.ix[i, 'Title']=df.ix[i, 'Title'].partition(',')[2]
    return df

# Function for extracting all possible titles
def title_extract(df):
    title_names=list(pd.unique(df['Title']).ravel())
    return title_names

# Function for creating a new column 'Martial_status'
def title_replace(df):
    title_names_Mr=[' Don', ' Major', ' Capt', ' Jonkheer', ' Rev', ' Col', ' Mr', ' Sir']
    title_names_Mrs=[' the Countess', ' Mme', ' Mrs',' Lady', ' Dona']
    title_names_Miss=[' Mlle', ' Ms',' Miss']
    title_names_Master=[' Master']
    for i in df.index: 
        if df.ix[i, 'Title'] in title_names_Mr:
            df.ix[i, 'Title']='Mr'
            df.ix[i, 'Title_mar']=1
        elif df.ix[i, 'Title'] in title_names_Mrs:
            df.ix[i, 'Title']='Mrs'
            df.ix[i, 'Title_mar']=1
        elif df.ix[i, 'Title'] in title_names_Miss:
            df.ix[i, 'Title']='Miss'
            df.ix[i, 'Title_mar']=0
        elif df.ix[i, 'Title'] in title_names_Master:
            df.ix[i, 'Title'] = 'Master'
            df.ix[i, 'Title_mar']=0
        elif df.ix[i, 'Title']in [' Dr', 'Dr']:
            if df.ix[i, 'Sex']=='male':
                df.ix[i, 'Title']='Mr'
                df.ix[i, 'Title_mar']=1
            else:
                df.ix[i, 'Title']='Mrs'
                df.ix[i, 'Title_mar']=1
    return df

# Function for replacing Sex with 0/1, Embarked with 0/1/2, dropping Embarked NaN and replacing Fare from 0 to NaN
def other_replace(df):
    df['Sex_01']=df['Sex'].map({'female':1, 'male':0}).astype(int)
    df=df.dropna(subset=['Embarked'], how='any')
    df['Embarked_01']=df['Embarked'].map({'S':0, 'C':1, 'Q':2}).astype(int)
    df.Fare = df.Fare.map(lambda x: np.nan if x==0 else x)
    return df

# Function for imputing values into Age field
def age_fill(df):
    median_ages = np.zeros((2,3))
    for j in range(0, 2):
        for k in range (0,3):
            median_ages[j,k] = df[(df['Title_mar'] == j) &(df['Pclass'] == k+1)]['Age'].dropna().median()       
    for j in range(0, 2):
        for k in range (0,3):
            df.loc[ (df.Age.isnull()) & (df['Title_mar'] == j) & (df.Pclass == k+1),\
                'Age'] = median_ages[j,k]
    print median_ages
    return df

# Function for imputing values into Fare field
def fare_fill(df):
    df['Family_Size']=df['SibSp']+df['Parch']+1
    df['Fare_pp']=df['Fare']/df['Family_Size']

    average_fares = np.zeros((3,3))
    for j in range(0, 3):
        for k in range (0,3):
            average_fares[j,k] =df[(df['Embarked_01'] == j) &(df['Pclass'] == k+1)]['Fare_pp'].dropna().median()
    for j in range(0, 3):
        for k in range (0,3):
            df.loc[ (df.Fare_pp.isnull()) & (df['Embarked_01']== j) & (df['Pclass'] == k+1),'Fare_pp'] = average_fares[j,k]
    return df

# Function for creating a dummies tabel for Embarked
def embarked_dummies(df):
    df_dummies=pd.get_dummies(df['Embarked'])
    df=df.join(df_dummies)
    return df

# %%
df=title_fill(df)
tn=title_extract(df)
df=title_replace(df)
df=other_replace(df)
df=age_fill(df)
df=fare_fill(df)
df
# Out:
# [[ 26.  18.  12.]
#  [ 42.  31.  28.]]
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# 25            26         1       3
# 26            27         0       3
# 27            28         0       1
# 28            29         1       3
# 29            30         0       3
# ..           ...       ...     ...
# 861          862         0       2
# 862          863         1       1
# 863          864         0       3
# 864          865         0       2
# 865          866         1       2
# 866          867         1       2
# 867          868         0       1
# 868          869         0       3
# 869          870         1       3
# 870          871         0       3
# 871          872         1       1
# 872          873         0       1
# 873          874         0       3
# 874          875         1       2
# 875          876         1       3
# 876          877         0       3
# 877          878         0       3
# 878          879         0       3
# 879          880         1       1
# 880          881         1       2
# 881          882         0       3
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male   22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                               Heikkinen, Miss. Laina  female   26      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                             Allen, Mr. William Henry    male   35      0
# 5                                     Moran, Mr. James    male   28      0
# 6                              McCarthy, Mr. Timothy J    male   54      0
# 7                       Palsson, Master. Gosta Leonard    male    2      3
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female   27      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female   14      1
# 10                     Sandstrom, Miss. Marguerite Rut  female    4      1
# 11                            Bonnell, Miss. Elizabeth  female   58      0
# 12                      Saundercock, Mr. William Henry    male   20      0
# 13                         Andersson, Mr. Anders Johan    male   39      1
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female   14      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female   55      0
# 16                                Rice, Master. Eugene    male    2      4
# 17                        Williams, Mr. Charles Eugene    male   31      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female   31      1
# 19                             Masselmani, Mrs. Fatima  female   28      0
# 20                                Fynney, Mr. Joseph J    male   35      0
# 21                               Beesley, Mr. Lawrence    male   34      0
# 22                         McGowan, Miss. Anna "Annie"  female   15      0
# 23                        Sloper, Mr. William Thompson    male   28      0
# 24                       Palsson, Miss. Torborg Danira  female    8      3
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female   38      1
# 26                             Emir, Mr. Farred Chehab    male   28      0
# 27                      Fortune, Mr. Charles Alexander    male   19      3
# 28                       O'Dwyer, Miss. Ellen "Nellie"  female   12      0
# 29                                 Todoroff, Mr. Lalio    male   28      0
# ..                                                 ...     ...  ...    ...
# 861                        Giles, Mr. Frederick Edward    male   21      1
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female   48      0
# 863                  Sage, Miss. Dorothy Edith "Dolly"  female   12      8
# 864                             Gill, Mr. John William    male   24      0
# 865                           Bystrom, Mrs. (Karolina)  female   42      0
# 866                       Duran y More, Miss. Asuncion  female   27      1
# 867               Roebling, Mr. Washington Augustus II    male   31      0
# 868                        van Melkebeke, Mr. Philemon    male   28      0
# 869                    Johnson, Master. Harold Theodor    male    4      1
# 870                                  Balkic, Mr. Cerin    male   26      0
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female   47      1
# 872                           Carlsson, Mr. Frans Olof    male   33      0
# 873                        Vander Cruyssen, Mr. Victor    male   47      0
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)  female   28      1
# 875                   Najib, Miss. Adele Kiamie "Jane"  female   15      0
# 876                      Gustafsson, Mr. Alfred Ossian    male   20      0
# 877                               Petroff, Mr. Nedelio    male   19      0
# 878                                 Laleff, Mr. Kristo    male   28      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female   56      0
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female   25      0
# 881                                 Markun, Mr. Johann    male   33      0
# 882                       Dahlberg, Miss. Gerda Ulrika  female   22      0
# 883                      Banfield, Mr. Frederick James    male   28      0
# 884                             Sutehall, Mr. Henry Jr    male   25      0
# 885               Rice, Mrs. William (Margaret Norton)  female   39      0
# 886                              Montvila, Rev. Juozas    male   27      0
# 887                       Graham, Miss. Margaret Edith  female   19      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   12      1
# 889                              Behr, Mr. Karl Howell    male   26      0
# 890                                Dooley, Mr. Patrick    male   32      0
#
#      Parch            Ticket      Fare        Cabin Embarked   Title  \
# 0        0         A/5 21171    7.2500          NaN        S      Mr
# 1        0          PC 17599   71.2833          C85        C     Mrs
# 2        0  STON/O2. 3101282    7.9250          NaN        S    Miss
# 3        0            113803   53.1000         C123        S     Mrs
# 4        0            373450    8.0500          NaN        S      Mr
# 5        0            330877    8.4583          NaN        Q      Mr
# 6        0             17463   51.8625          E46        S      Mr
# 7        1            349909   21.0750          NaN        S  Master
# 8        2            347742   11.1333          NaN        S     Mrs
# 9        0            237736   30.0708          NaN        C     Mrs
# 10       1           PP 9549   16.7000           G6        S    Miss
# 11       0            113783   26.5500         C103        S    Miss
# 12       0         A/5. 2151    8.0500          NaN        S      Mr
# 13       5            347082   31.2750          NaN        S      Mr
# 14       0            350406    7.8542          NaN        S    Miss
# 15       0            248706   16.0000          NaN        S     Mrs
# 16       1            382652   29.1250          NaN        Q  Master
# 17       0            244373   13.0000          NaN        S      Mr
# 18       0            345763   18.0000          NaN        S     Mrs
# 19       0              2649    7.2250          NaN        C     Mrs
# 20       0            239865   26.0000          NaN        S      Mr
# 21       0            248698   13.0000          D56        S      Mr
# 22       0            330923    8.0292          NaN        Q    Miss
# 23       0            113788   35.5000           A6        S      Mr
# 24       1            349909   21.0750          NaN        S    Miss
# 25       5            347077   31.3875          NaN        S     Mrs
# 26       0              2631    7.2250          NaN        C      Mr
# 27       2             19950  263.0000  C23 C25 C27        S      Mr
# 28       0            330959    7.8792          NaN        Q    Miss
# 29       0            349216    7.8958          NaN        S      Mr
# ..     ...               ...       ...          ...      ...     ...
# 861      0             28134   11.5000          NaN        S      Mr
# 862      0             17466   25.9292          D17        S     Mrs
# 863      2          CA. 2343   69.5500          NaN        S    Miss
# 864      0            233866   13.0000          NaN        S      Mr
# 865      0            236852   13.0000          NaN        S     Mrs
# 866      0     SC/PARIS 2149   13.8583          NaN        C    Miss
# 867      0          PC 17590   50.4958          A24        S      Mr
# 868      0            345777    9.5000          NaN        S      Mr
# 869      1            347742   11.1333          NaN        S  Master
# 870      0            349248    7.8958          NaN        S      Mr
# 871      1             11751   52.5542          D35        S     Mrs
# 872      0               695    5.0000  B51 B53 B55        S      Mr
# 873      0            345765    9.0000          NaN        S      Mr
# 874      0         P/PP 3381   24.0000          NaN        C     Mrs
# 875      0              2667    7.2250          NaN        C    Miss
# 876      0              7534    9.8458          NaN        S      Mr
# 877      0            349212    7.8958          NaN        S      Mr
# 878      0            349217    7.8958          NaN        S      Mr
# 879      1             11767   83.1583          C50        C     Mrs
# 880      1            230433   26.0000          NaN        S     Mrs
# 881      0            349257    7.8958          NaN        S      Mr
# 882      0              7552   10.5167          NaN        S    Miss
# 883      0  C.A./SOTON 34068   10.5000          NaN        S      Mr
# 884      0   SOTON/OQ 392076    7.0500          NaN        S      Mr
# 885      5            382652   29.1250          NaN        Q     Mrs
# 886      0            211536   13.0000          NaN        S      Mr
# 887      0            112053   30.0000          B42        S    Miss
# 888      2        W./C. 6607   23.4500          NaN        S    Miss
# 889      0            111369   30.0000         C148        C      Mr
# 890      0            370376    7.7500          NaN        Q      Mr
#
#      Title_mar  Sex_01  Embarked_01  Family_Size    Fare_pp
# 0            1       0            0            2   3.625000
# 1            1       1            1            2  35.641650
# 2            0       1            0            1   7.925000
# 3            1       1            0            2  26.550000
# 4            1       0            0            1   8.050000
# 5            1       0            2            1   8.458300
# 6            1       0            0            1  51.862500
# 7            0       0            0            5   4.215000
# 8            1       1            0            3   3.711100
# 9            1       1            1            2  15.035400
# 10           0       1            0            3   5.566667
# 11           0       1            0            1  26.550000
# 12           1       0            0            1   8.050000
# 13           1       0            0            7   4.467857
# 14           0       1            0            1   7.854200
# 15           1       1            0            1  16.000000
# 16           0       0            2            6   4.854167
# 17           1       0            0            1  13.000000
# 18           1       1            0            2   9.000000
# 19           1       1            1            1   7.225000
# 20           1       0            0            1  26.000000
# 21           1       0            0            1  13.000000
# 22           0       1            2            1   8.029200
# 23           1       0            0            1  35.500000
# 24           0       1            0            5   4.215000
# 25           1       1            0            7   4.483929
# 26           1       0            1            1   7.225000
# 27           1       0            0            6  43.833333
# 28           0       1            2            1   7.879200
# 29           1       0            0            1   7.895800
# ..         ...     ...          ...          ...        ...
# 861          1       0            0            2   5.750000
# 862          1       1            0            1  25.929200
# 863          0       1            0           11   6.322727
# 864          1       0            0            1  13.000000
# 865          1       1            0            1  13.000000
# 866          0       1            1            2   6.929150
# 867          1       0            0            1  50.495800
# 868          1       0            0            1   9.500000
# 869          0       0            0            3   3.711100
# 870          1       0            0            1   7.895800
# 871          1       1            0            3  17.518067
# 872          1       0            0            1   5.000000
# 873          1       0            0            1   9.000000
# 874          1       1            1            2  12.000000
# 875          0       1            1            1   7.225000
# 876          1       0            0            1   9.845800
# 877          1       0            0            1   7.895800
# 878          1       0            0            1   7.895800
# 879          1       1            1            2  41.579150
# 880          1       1            0            2  13.000000
# 881          1       0            0            1   7.895800
# 882          0       1            0            1  10.516700
# 883          1       0            0            1  10.500000
# 884          1       0            0            1   7.050000
# 885          1       1            2            6   4.854167
# 886          1       0            0            1  13.000000
# 887          0       1            0            1  30.000000
# 888          0       1            0            4   5.862500
# 889          1       0            1            1  30.000000
# 890          1       0            2            1   7.750000
#
# [889 rows x 18 columns]

# %% [markdown]
# %matplotlib inline
# from pandas.tools.plotting import scatter_matrix
# scat = scatter_matrix(df, figsize = (15,15))

# %% [markdown]
# ###### Logistic regression

# %%
features = np.array(df[['Age','Title_mar', 'Pclass', 'Family_Size', 'Fare_pp', 'Sex_01']])
target = np.array(df['Survived'])
#features_norm = (features - features.mean())/features.std()

# %% [markdown]
# I just used a cross validaton function

# %%
from sklearn.cross_validation import KFold

def cross_validate(X, y, classifier, k_fold) :

    # derive a set of (random) training and testing indices
    k_fold_indices = KFold(len(X), n_folds=k_fold,
                           shuffle=True, random_state=0)

    k_score_total = 0
    # for each training and testing slices run the classifier, and score the results
    for train_slice, test_slice in k_fold_indices :

        model = classifier(X[ train_slice  ],
                         y[ train_slice  ])
        k_score = model.score(X[ test_slice ],
                              y[ test_slice ])

        k_score_total += k_score

    # return the average accuracy
    return k_score_total/k_fold

# %%
model_lr = LogisticRegression(C=1).fit(features, target)

#cross_validate(features, target, model_lr, 10)

model_lr.coef_.ravel()
# Out:
# array([-0.03220952, -0.22520412, -1.0496684 , -0.19006816,  0.00399883,
#         2.48570916])

# %% [markdown]
# ###### Equation output

# %%
train_feat, test_feat, train_target, test_target = train_test_split(features, target, train_size=0.5)
target_predicted_proba = model_lr.predict_proba(test_feat)

# %%
def plot_roc_curve(target_test, target_predicted_proba):
    fpr, tpr, thresholds = roc_curve(target_test, target_predicted_proba[:, 1
                                                                         ])
    roc_auc = auc(fpr, tpr)
    
    # Plot ROC curve
    plt.plot(fpr, tpr, label='ROC curve (area = %0.3f)' % roc_auc)
    plt.plot([0, 1], [0, 1], 'k--')  # random predictions curve
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.0])
    plt.xlabel('False Positive Rate or (1 - Specifity)')
    plt.ylabel('True Positive Rate or (Sensitivity)')
    plt.title('Receiver Operating Characteristic')
    plt.legend(loc="lower right")
    
plot_roc_curve(test_target, target_predicted_proba)

# %% [markdown]
# Choosing a threshod value

# %% [markdown]
# ###### Importing the out of sample data (test.csv is this case)

# %%
dft=pd.read_csv('test.csv')

# %% [markdown]
# I am going to apply the same functions to clean and transform data for further input into

# %%
dft=title_fill(dft)
tnt=title_extract(dft)
tn=title_extract(df)
print tnt
# I just printed both to make sure I dont have to modify the function of replacing titles for a test dataset, and indeed -  I foulf a new one (' Dona')
# Out:
# [' Mr', ' Mrs', ' Miss', ' Master', ' Ms', ' Col', ' Rev', ' Dr', ' Dona']

# %%
dft=title_replace(dft)
dft=other_replace(dft)
dft=age_fill(dft)
dft=fare_fill(dft)

# %%
dft.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked Title  Title_mar  \
# 0  34.5      0      0   330911   7.8292   NaN        Q    Mr          1
# 1  47.0      1      0   363272   7.0000   NaN        S   Mrs          1
# 2  62.0      0      0   240276   9.6875   NaN        Q    Mr          1
# 3  27.0      0      0   315154   8.6625   NaN        S    Mr          1
# 4  22.0      1      1  3101298  12.2875   NaN        S   Mrs          1
#
#    Sex_01  Embarked_01  Family_Size   Fare_pp
# 0       0            2            1  7.829200
# 1       1            0            2  3.500000
# 2       0            2            1  9.687500
# 3       0            0            1  8.662500
# 4       1            0            3  4.095833

# %% [markdown]
# ###### a. Make sure your model results are reproducible by the instructor team, given any random aspects to your code / steps.

# %% [markdown]
# Involve such constructions as create Table is exists etc
# Any directories

# %% [markdown]
# ###### b. Show your model output. Include coefficient values.

# %% [markdown]
# Output as an equation'
# Output as a python function

# %% [markdown]
# ###### c. Explain which features are predictive for this logistic regression and,
# intuitively, why you think this may be so. Describe your thinking / logic
# in words. It is not sufficient to cite output statistics.

# %% [markdown]
# explain the results/story telling/include nice visuals

# %% [markdown]
# ###### d. Make sure that you can push new data points through your model to get
# regression output. We will be providing a test set for this purpose.

# %% [markdown]
# test/train split + out of sample data (include room for it)

# %% [markdown]
# ###### 3. Implement cross-validation for your logistic regression. Pick the number of folds. Explain your choice.

# %%
The number of folds will depend on the cross validation score

# %% [markdown]
# ###### 4. Create an ROC curve for your logistic regression by varying the threshold value for survival.

# %% [markdown]
# The Confusion matrix can exist for more than two different states. But ROC curve looks nive because its tow dimentional

# %% [markdown]
# ROC curve is showing the sensitivity and specificity scores
# ROC: Receiver Operating Characteristic

# %% [markdown]
# ###### b. What is the AUC for your model?

# %% [markdown]
# what is the goal of the model? Which types of errors are accepted and which are not?

# %% [markdown]
# AUC - Area under curve

# %% [markdown]
# ###### c. Explain why the model has achieved this level of accuracy/precision.

# %% [markdown]
# hmmm

# %% [markdown]
# ###### d. Explain how you could improve these metrics, as potential next steps.

# %% [markdown]
# hmmm

# %% [markdown]
# ###### e. Armed with this knowledge, what threshold value would you use? Why?
# Describe your thinking.

# %% [markdown]
# hmm
