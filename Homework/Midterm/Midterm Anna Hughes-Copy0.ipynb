# %% [markdown]
# ###### Importing data

# %% [markdown]
# There is no tickets which cost 0. So I replace 0 with NaN

# %%
import pandas as pd
import numpy as np
import string
import statsmodels.api as sm
df=pd.read_csv('train.csv')
df

# %% [markdown]
# ###### Extracting Titles from Names

# %%
for i in df.index: 
    df.ix[i, 'Title']=df.ix[i, 'Name'].partition('.')[0]
    df.ix[i, 'Title']=df.ix[i, 'Title'].partition(',')[2]
Title_names=list(pd.unique(df['Title'].values.ravel()))
print Title_names

# %% [markdown]
# Replacing titles with codes
# 0 for male, 1 for female (Title_sex)
# 0 for young, 1 for mature (Title_age)
# There are 4 titles left Mr, Mrs, Miss and Master

# %%
for i in df.index: 
    if df.ix[i, 'Title'] in [' Don', ' Major', ' Capt', ' Jonkheer', ' Rev', ' Col', ' Mr', ' Sir', 'Mr']:
        df.ix[i, 'Title']='Mr'
        df.ix[i, 'Title_sex']=0
        df.ix[i, 'Title_age']=1
    elif df.ix[i, 'Title'] in [' the Countess', ' Mme', ' Mrs',' Lady', 'Mrs']:
        df.ix[i, 'Title']='Mrs'
        df.ix[i, 'Title_sex']=1
        df.ix[i, 'Title_age']=1
    elif df.ix[i, 'Title'] in [' Mlle', ' Ms',' Miss', 'Miss']:
        df.ix[i, 'Title']='Miss'
        df.ix[i, 'Title_sex']=1
        df.ix[i, 'Title_age']=0
    elif df.ix[i, 'Title'] in [' Master', 'Master']:
        df.ix[i, 'Title'] = 'Master'
        df.ix[i, 'Title_sex']=0
        df.ix[i, 'Title_age']=0
    elif df.ix[i, 'Title']in [' Dr', 'Dr']:
        if df.ix[i, 'Sex']=='male':
            df.ix[i, 'Title']='Mr'
            df.ix[i, 'Title_sex']=0
            df.ix[i, 'Title_age']=1
        else:
            df.ix[i, 'Title']='Mrs'
            df.ix[i, 'Title_sex']=1
            df.ix[i, 'Title_age']=1
            
Title_names=list(pd.unique(df['Title'].values.ravel()))
print Title_names

# %% [markdown]
# Here I am going to replace Sex with a 0/1 value (0 male, 1 female)

# %%
df['Sex_01']=df['Sex'].map({'female':1, 'male':0}).astype(int)

# %% [markdown]
# Checking whether the initial Sex values corresponds to the one derived from Title

# %%
for i in df.index: 
    if df.ix[i,'Sex_01']<>df.ix[i,'Title_sex']:
        print df.ix[i,'Name']
# nothing is printed because all data is consistent

# %% [markdown]
# I will use 3 dimensions to calculate the average age for.
# 1. Sex (equal to title_sex)
# 2. Title_age
# 3. Cabin class

# %%
median_ages = np.zeros((2,2,3))
for i in range(0, 2):
    for j in range(0, 2):
        for k in range (0,3):
            median_ages[i,j,k] = df[(df['Title_sex'] == i) &(df['Title_age'] == j) &(df['Pclass'] == k+1)]['Age'].dropna().median()
median_ages[:,0,:]

# %%
for i in range(0, 2):
    for j in range(0, 2):
        for k in range (0,3):
            df.loc[ (df.Age.isnull()) & (df['Title_sex'] == i)&(df['Title_age'] == j) & (df.Pclass == k+1),\
                'Age'] = median_ages[i,j,k]

# %% [markdown]
# Dropping records with missing values for 'embarked'

# %%
df=df.dropna(subset=['Embarked'], how='any')

# %% [markdown]
# ###### Cabins

# %% [markdown]
# I am going to explore the data about cabins (there are only around 200 entries for this data)
# Common sense is that that

# %%
cabin_names=list(pd.unique(df['Cabin'].values.ravel()))
df['Cabin']=df['Cabin'].astype(str)

for i in df.index: 
    if df.ix[i, 'Cabin']<>np.nan:
        df.ix[i, 'Deck']=df.ix[i, 'Cabin'][0]
        print df.ix[i, 'Deck']
    else:
        df.ix[i, 'Cabin']=np.nan
        df.ix[i, 'Deck']=np.nan
        print df.ix[i, 'Deck']
deck_names=list(pd.unique(df['Deck'].values.ravel()))
print deck_names
#df_cabins=df.dropna(subset=['Cabin'], how='any')

# %%
median_ages = np.zeros((2,2,3))
for i in range(0, 2):
    for j in range(0, 2):
        for k in range (0,3):
            median_ages[i,j,k] = df[(df['Title_sex'] == i) &(df['Title_age'] == j) &(df['Pclass'] == k+1)]['Age'].dropna().median()
median_ages[:,0,:]

# %% [markdown]
# There are Fares=0 what cannot be true and Im'm going to replace them with average Fare for the Pclass and Cabin
# Also the fares are for an overall family, so I am going to calculate the size of family and divide the fare by it

# %%
df['Family_Size']=df['SibSp']+df['Parch']+1
df['Fare_pp']=df['Fare']/df['Family_Size']
df.sort(columns='Fare')
# Out:
#      PassengerId  Survived  Pclass  \
# 271          272         1       3
# 597          598         0       3
# 302          303         0       3
# 633          634         0       1
# 277          278         0       2
# 413          414         0       2
# 674          675         0       2
# 263          264         0       1
# 466          467         0       2
# 732          733         0       2
# 179          180         0       3
# 806          807         0       1
# 481          482         0       2
# 822          823         0       1
# 815          816         0       1
# 378          379         0       3
# 872          873         0       1
# 326          327         0       3
# 843          844         0       3
# 818          819         0       3
# 202          203         0       3
# 371          372         0       3
# 654          655         0       3
# 143          144         0       3
# 411          412         0       3
# 825          826         0       3
# 129          130         0       3
# 804          805         1       3
# 477          478         0       3
# 884          885         0       3
# ..           ...       ...     ...
# 195          196         1       1
# 297          298         0       1
# 498          499         0       1
# 708          709         1       1
# 305          306         1       1
# 332          333         0       1
# 609          610         1       1
# 268          269         1       1
# 318          319         1       1
# 856          857         1       1
# 689          690         1       1
# 730          731         1       1
# 779          780         1       1
# 377          378         0       1
# 527          528         0       1
# 380          381         1       1
# 557          558         0       1
# 700          701         1       1
# 716          717         1       1
# 299          300         1       1
# 118          119         0       1
# 311          312         1       1
# 742          743         1       1
# 27            28         0       1
# 438          439         0       1
# 341          342         1       1
# 88            89         1       1
# 737          738         1       1
# 679          680         1       1
# 258          259         1       1
#
#                                                   Name     Sex    Age  SibSp  \
# 271                       Tornquist, Mr. William Henry    male  25.00      0
# 597                                Johnson, Mr. Alfred    male  49.00      0
# 302                    Johnson, Mr. William Cahoone Jr    male  19.00      0
# 633                      Parr, Mr. William Henry Marsh    male  42.00      0
# 277                        Parkes, Mr. Francis "Frank"    male  31.00      0
# 413                     Cunningham, Mr. Alfred Fleming    male  31.00      0
# 674                         Watson, Mr. Ennis Hastings    male  31.00      0
# 263                              Harrison, Mr. William    male  40.00      0
# 466                              Campbell, Mr. William    male  31.00      0
# 732                               Knight, Mr. Robert J    male  31.00      0
# 179                                Leonard, Mr. Lionel    male  36.00      0
# 806                             Andrews, Mr. Thomas Jr    male  39.00      0
# 481                   Frost, Mr. Anthony Wood "Archie"    male  31.00      0
# 806      0           112050    0.0000              A36        S      Mr
# 481      0           239854    0.0000              nan        S      Mr
# 822      0            19972    0.0000              nan        S      Mr
# 815      0           112058    0.0000             B102        S      Mr
# 378      0             2648    4.0125              nan        C      Mr
# 872      0              695    5.0000      B51 B53 B55        S      Mr
# 326      0           345364    6.2375              nan        S      Mr
# 843      0             2683    6.4375              nan        C      Mr
# 818      0           C 7075    6.4500              nan        S      Mr
# 202      0          3101264    6.4958              nan        S      Mr
# 371      0          3101267    6.4958              nan        S      Mr
# 654      0           365226    6.7500              nan        Q    Miss
# 143      0           365222    6.7500              nan        Q      Mr
# 411      0           394140    6.8583              nan        Q      Mr
# 825      0           368323    6.9500              nan        Q      Mr
# 129      0           347061    6.9750              nan        S      Mr
# 804      0           347089    6.9750              nan        S      Mr
# 477      0             3460    7.0458              nan        S      Mr
# 884      0  SOTON/OQ 392076    7.0500              nan        S      Mr
# ..     ...              ...       ...              ...      ...     ...
# 195      0         PC 17569  146.5208              B80        C    Miss
# 297      2           113781  151.5500          C22 C26        S    Miss
# 498      2           113781  151.5500          C22 C26        S     Mrs
# 708      0           113781  151.5500              nan        S    Miss
# 305      2           113781  151.5500          C22 C26        S  Master
# 332      1         PC 17582  153.4625              C91        S      Mr
# 609      0         PC 17582  153.4625             C125        S    Miss
# 268      1         PC 17582  153.4625             C125        S     Mrs
# 318      2            36928  164.8667               C7        S    Miss
# 856      1            36928  164.8667              nan        S     Mrs
# 689      1            24160  211.3375               B5        S    Miss
# 730      0            24160  211.3375               B5        S    Miss
# 779      1            24160  211.3375               B3        S     Mrs
# 377      2           113503  211.5000              C82        C      Mr
# 527      0         PC 17483  221.7792              C95        S      Mr
# 380      0         PC 17757  227.5250              nan        C    Miss
# 557      0         PC 17757  227.5250              nan        C      Mr
# 700      0         PC 17757  227.5250          C62 C64        C     Mrs
# 716      0         PC 17757  227.5250              C45        C    Miss
# 299      1         PC 17558  247.5208          B58 B60        C     Mrs
# 118      1         PC 17558  247.5208          B58 B60        C      Mr
# 311      2         PC 17608  262.3750  B57 B59 B63 B66        C    Miss
# 742      2         PC 17608  262.3750  B57 B59 B63 B66        C    Miss
# 27       2            19950  263.0000      C23 C25 C27        S      Mr
# 438      4            19950  263.0000      C23 C25 C27        S      Mr
# 341      2            19950  263.0000      C23 C25 C27        S    Miss
# 88       2            19950  263.0000      C23 C25 C27        S    Miss
# 737      0         PC 17755  512.3292             B101        C      Mr
# 679      1         PC 17755  512.3292      B51 B53 B55        C      Mr
# 258      0         PC 17755  512.3292              nan        C    Miss
#
#      Title_sex  Title_age  Sex_01 Deck  Family_Size     Fare_pp
# 271          0          1       0    n            1    0.000000
# 597          0          1       0    n            1    0.000000
# 302          0          1       0    n            1    0.000000
# 633          0          1       0    n            1    0.000000
# 277          0          1       0    n            1    0.000000
# 413          0          1       0    n            1    0.000000
# 674          0          1       0    n            1    0.000000
# 263          0          1       0    B            1    0.000000
# 466          0          1       0    n            1    0.000000
# 732          0          1       0    n            1    0.000000
# 179          0          1       0    n            1    0.000000
# 806          0          1       0    A            1    0.000000
# 481          0          1       0    n            1    0.000000
# 822          0          1       0    n            1    0.000000
# 815          0          1       0    B            1    0.000000
# 378          0          1       0    n            1    4.012500
# 872          0          1       0    B            1    5.000000
# 326          0          1       0    n            1    6.237500
# 843          0          1       0    n            1    6.437500
# 818          0          1       0    n            1    6.450000
# 202          0          1       0    n            1    6.495800
# 371          0          1       0    n            2    3.247900
# 654          1          0       1    n            1    6.750000
# 143          0          1       0    n            1    6.750000
# 411          0          1       0    n            1    6.858300
# 825          0          1       0    n            1    6.950000
# 129          0          1       0    n            1    6.975000
# 804          0          1       0    n            1    6.975000
# 477          0          1       0    n            2    3.522900
# 884          0          1       0    n            1    7.050000
# ..         ...        ...     ...  ...          ...         ...
# 195          1          0       1    B            1  146.520800
# 297          1          0       1    C            4   37.887500
# 498          1          1       1    C            4   37.887500
# 708          1          0       1    n            1  151.550000
# 305          0          0       0    C            4   37.887500
# 332          0          1       0    C            2   76.731250
# 609          1          0       1    C            1  153.462500
# 268          1          1       1    C            2   76.731250
# 318          1          0       1    C            3   54.955567
# 856          1          1       1    n            3   54.955567
# 689          1          0       1    B            2  105.668750
# 730          1          0       1    B            1  211.337500
# 779          1          1       1    B            2  105.668750
# 377          0          1       0    C            3   70.500000
# 527          0          1       0    C            1  221.779200
# 380          1          0       1    n            1  227.525000
# 557          0          1       0    n            1  227.525000
# 700          1          1       1    C            2  113.762500
# 716          1          0       1    C            1  227.525000
# 299          1          1       1    B            2  123.760400
# 118          0          1       0    B            2  123.760400
# 311          1          0       1    B            5   52.475000
# 742          1          0       1    B            5   52.475000
# 27           0          1       0    C            6   43.833333
# 438          0          1       0    C            6   43.833333
# 341          1          0       1    C            6   43.833333
# 88           1          0       1    C            6   43.833333
# 737          0          1       0    B            1  512.329200
# 679          0          1       0    B            2  256.164600
# 258          1          0       1    n            1  512.329200
#
# [889 rows x 19 columns]

# %%
df.sort(columns='Name')
# Out:
#      PassengerId  Survived  Pclass  \
# 845          846         0       3
# 746          747         0       3
# 279          280         1       3
# 308          309         0       2
# 874          875         1       2
# 365          366         0       3
# 401          402         0       3
# 40            41         0       3
# 855          856         1       3
# 207          208         1       3
# 810          811         0       3
# 840          841         0       3
# 210          211         0       3
# 784          785         0       3
# 730          731         1       1
# 4              5         0       3
# 305          306         1       1
# 297          298         0       1
# 498          499         0       1
# 834          835         0       3
# 192          193         1       3
# 460          461         1       1
# 850          851         0       3
# 813          814         0       3
# 119          120         0       3
# 68            69         1       3
# 541          542         0       3
# 542          543         0       3
# 13            14         0       3
# 146          147         1       3
# ..           ...       ...     ...
# 406          407         0       3
# 377          378         0       1
# 371          372         0       3
# 673          674         1       2
# 648          649         0       3
# 155          156         0       1
# 17            18         1       2
# 304          305         0       3
# 735          736         0       3
# 351          352         0       1
# 491          492         0       3
# 425          426         0       3
# 55            56         1       1
# 555          556         0       1
# 620          621         0       3
# 830          831         1       3
# 325          326         1       1
# 203          204         0       3
# 354          355         0       3
# 495          496         0       3
# 199          200         0       2
# 111          112         0       3
# 240          241         0       3
# 422          423         0       3
# 559          560         1       3
# 286          287         1       3
# 282          283         0       3
# 361          362         0       2
# 153          154         0       3
# 868          869         0       3
#
#                                                 Name     Sex    Age  SibSp  \
# 845                              Abbing, Mr. Anthony    male  42.00      0
# 746                      Abbott, Mr. Rossmore Edward    male  16.00      1
# 279                 Abbott, Mrs. Stanton (Rosa Hunt)  female  35.00      1
# 308                              Abelson, Mr. Samuel    male  30.00      1
# 874            Abelson, Mrs. Samuel (Hannah Wizosky)  female  28
# 559     de Messemaeker, Mrs. Guillaume Joseph (Emma)  female  36.00      1
# 286                          de Mulder, Mr. Theodore    male  30.00      0
# 282                        de Pelsmaeker, Mr. Alfons    male  16.00      0
# 361                        del Carlo, Mr. Sebastiano    male  29.00      1
# 153                  van Billiard, Mr. Austin Blyler    male  40.50      0
# 868                      van Melkebeke, Mr. Philemon    male  26.00      0
#
#      Parch              Ticket      Fare    Cabin Embarked   Title  Title_sex  \
# 845      0           C.A. 5547    7.5500      NaN        S      Mr          0
# 746      1           C.A. 2673   20.2500      NaN        S      Mr          0
# 279      1           C.A. 2673   20.2500      NaN        S     Mrs          1
# 308      0           P/PP 3381   24.0000      NaN        C      Mr          0
# 874      0           P/PP 3381   24.0000      NaN        C     Mrs          1
# 365      0              C 7076    7.2500      NaN        S      Mr          0
# 401      0              341826    8.0500      NaN        S      Mr          0
# 40       0                7546    9.4750      NaN        S     Mrs          1
# 855      1              392091    9.3500      NaN        S     Mrs          1
# 207      0                2699   18.7875      NaN        C      Mr          0
# 810      0                3474    7.8875      NaN        S      Mr          0
# 840      0    SOTON/O2 3101287    7.9250      NaN        S      Mr          0
# 210      0  SOTON/O.Q. 3101311    7.0500      NaN        S      Mr          0
# 784      0  SOTON/O.Q. 3101312    7.0500      NaN        S      Mr          0
# 730      0               24160  211.3375       B5        S    Miss          1
# 4        0              373450    8.0500      NaN        S      Mr          0
# 305      2              113781  151.5500  C22 C26        S  Master          0
# 297      2              113781  151.5500  C22 C26        S    Miss          1
# 498      2              113781  151.5500  C22 C26        S     Mrs          1
# 834      0                2223    8.3000      NaN        S      Mr          0
# 192      0              350046    7.8542      NaN        S    Miss          1
# 460      0               19952   26.5500      E12        S      Mr          0
# 850      2              347082   31.2750      NaN        S  Master          0
# 813      2              347082   31.2750      NaN        S    Miss          1
# 119      2              347082   31.2750      NaN        S    Miss          1
# 68       2             3101281    7.9250      NaN        S    Miss          1
# 541      2              347082   31.2750      NaN        S    Miss          1
# 542      2              347082   31.2750      NaN        S    Miss          1
# 13       5              347082   31.2750      NaN        S      Mr          0
# 146      0              350043    7.7958      NaN        S      Mr          0
# ..     ...                 ...       ...      ...      ...     ...        ...
# 406      0              347064    7.7500      NaN        S      Mr          0
# 377      2              113503  211.5000      C82        C      Mr          0
# 371      0             3101267    6.4958      NaN        S      Mr          0
# 673      0              244270   13.0000      NaN        S      Mr          0
# 648      0       S.O./P.P. 751    7.5500      NaN        S      Mr          0
# 155      1            PC 17597   61.3792      NaN        C      Mr          0
# 17       0              244373   13.0000      NaN        S      Mr          0
# 304      0            A/5 2466    8.0500      NaN        S      Mr          0
# 735      0               54636   16.1000      NaN        S      Mr          0
# 351      0              113510   35.0000     C128        S      Mr          0
# 491      0    SOTON/OQ 3101317    7.2500      NaN        S      Mr          0
# 425      0          A/4. 34244    7.2500      NaN        S      Mr          0
# 55       0               19947   35.5000      C52        S      Mr          0
# 555      0              113807   26.5500      NaN        S      Mr          0
# 620      0                2659   14.4542      NaN        C      Mr          0
# 830      0                2659   14.4542      NaN        C     Mrs          1
# 325      0            PC 17760  135.6333      C32        C    Miss          1
# 203      0                2628    7.2250      NaN        C      Mr          0
# 354      0                2647    7.2250      NaN        C      Mr          0
# 495      0                2627   14.4583      NaN        C      Mr          0
# 199      0              248747   13.0000      NaN        S    Miss          1
# 111      0                2665   14.4542      NaN        C    Miss          1
# 240      0                2665   14.4542      NaN        C    Miss          1
# 422      0              315082    7.8750      NaN        S      Mr          0
# 559      0              345572   17.4000      NaN        S     Mrs          1
# 286      0              345774    9.5000      NaN        S      Mr          0
# 282      0              345778    9.5000      NaN        S      Mr          0
# 361      0       SC/PARIS 2167   27.7208      NaN        C      Mr          0
# 153      2            A/5. 851   14.5000      NaN        S      Mr          0
# 868      0              345777    9.5000      NaN        S      Mr          0
#
#      Title_age  Sex_01  Family_Size     Fare_pp
# 845          1       0            1    7.550000
# 746          1       0            3    6.750000
# 279          1       1            3    6.750000
# 308          1       0            2   12.000000
# 874          1       1            2   12.000000
# 365          1       0            1    7.250000
# 401          1       0            1    8.050000
# 40           1       1            2    4.737500
# 855          1       1            2    4.675000
# 207          1       0            1   18.787500
# 810          1       0            1    7.887500
# 840          1       0            1    7.925000
# 210          1       0            1    7.050000
# 784          1       0            1    7.050000
# 730          0       1            1  211.337500
# 4            1       0            1    8.050000
# 305          0       0            4   37.887500
# 297          0       1            4   37.887500
# 498          1       1            4   37.887500
# 834          1       0            1    8.300000
# 192          0       1            2    3.927100
# 460          1       0            1   26.550000
# 850          0       0            7    4.467857
# 813          0       1            7    4.467857
# 119          0       1            7    4.467857
# 68           0       1            7    1.132143
# 541          0       1            7    4.467857
# 542          0       1            7    4.467857
# 13           1       0            7    4.467857
# 146          1       0            1    7.795800
# ..         ...     ...          ...         ...
# 406          1       0            1    7.750000
# 377          1       0            3   70.500000
# 371          1       0            2    3.247900
# 673          1       0            1   13.000000
# 648          1       0            1    7.550000
# 155          1       0            2   30.689600
# 17           1       0            1   13.000000
# 304          1       0            1    8.050000
# 735          1       0            1   16.100000
# 351          1       0            1   35.000000
# 491          1       0            1    7.250000
# 425          1       0            1    7.250000
# 55           1       0            1   35.500000
# 555          1       0            1   26.550000
# 620          1       0            2    7.227100
# 830          1       1            2    7.227100
# 325          0       1            1  135.633300
# 203          1       0            1    7.225000
# 354          1       0            1    7.225000
# 495          1       0            1   14.458300
# 199          0       1            1   13.000000
# 111          0       1            2    7.227100
# 240          0       1            2    7.227100
# 422          1       0            1    7.875000
# 559          1       1            2    8.700000
# 286          1       0            1    9.500000
# 282          1       0            1    9.500000
# 361          1       0            2   13.860400
# 153          1       0            3    4.833333
# 868          1       0            1    9.500000
#
# [889 rows x 18 columns]

# %% [markdown]
# I am going to run a multivariate regression to figure out how am I going to replace missing age values

# %% [raw]
# %matplotlib inline
# from pandas.tools.plotting import scatter_matrix
# scat = scatter_matrix(df, figsize = (10,10))

# %% [markdown]
# Feature's transformation

# %%
df['Embarked_012']=df['Embarked'].map({'S':0, 'C':1,'Q':2}).astype(int)

# %% [markdown]
# Doing PCA before feature engineering

# %% [raw]
# X=df['Pclass', 'Sex', 'Age', 'SibSp', 'Parch','Fare' ]
# y=df['Survived']
# print y
# from sklearn.decomposition import PCA
# pca = PCA(n_components=10)
# X = pca.fit(X).transform(X)

# %% [markdown]
# ###### Cabins

# %% [markdown]
# Hypothesis: the probvability of survival is affected by the location of the cabin. And location of the cabin is defined by its letter(A-F) and number (two-digit after letter)

# %%
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# 839      0        11774   29.7000          C47        C       0             1
# 849      0        17453   89.1042          C92        C       1             1
# 853      1     PC 17592   39.4000          D28        S       1             0
# 857      0       113055   26.5500          E17        S       0             0
# 862      0        17466   25.9292          D17        S       1             0
# 867      0     PC 17590   50.4958          A24        S       0             0
# 871      1        11751   52.5542          D35        S       1             0
# 872      0          695    5.0000  B51 B53 B55        S       0             0
# 879      1        11767   83.1583          C50        C       1             1
# 887      0       112053   30.0000          B42        S       1             0
# 889      0       111369   30.0000         C148        C       0             1
#
#     Cabin_letter Cabin_number
# 1              C           85
# 3              C          123
# 6              E           46
# 10             G            6
# 11             C          103
# 21             D           56
# 23             A            6
# 27             C          23
# 31             B           78
# 52             D           33
# 54             B           30
# 55             C           52
# 62             C           83
# 66             F           33
# 75             F           G7
# 88             C          23
# 92             E           31
# 96             A            5
# 97             D          10
# 102            D           26
# 110            C          110
# 118            B          58
# 123            E          101
# 124            D           26
# 128            F           E6
# 136            D           47
# 137            C          123
# 139            B           86
# 148            F            2
# 151            C            2
# ..           ...          ...
# 748            D           30
# 751            E          121
# 759            B           77
# 763            B          96
# 765            D           11
# 772            E           77
# 776            F           38
# 779            B            3
# 781            B           20
# 782            D            6
# 789            B          82
# 796            D           17
# 802            B          96
# 806            A           36
# 809            E            8
# 815            B          102
# 820            B           69
# 823            E          121
# 835            E           49
# 839            C           47
# 849            C           92
# 853            D           28
# 857            E           17
# 862            D           17
# 867            A           24
# 871            D           35
# 872            B          51
# 879            C           50
# 887            B           42
# 889            C          148
#
# [202 rows x 16 columns]

# %%
#df_cabins['Cabin_letter']=df_cabins['Cabin_letter'].map({'A':0,'B':1,'C':2,'D':3, 'E':4, 'F':5,'G':6}).astype(float)
#df_cabins['Cabin_letter']

df_cabins_dummies=pd.get_dummies(df_cabins['Cabin_letter'])
df_cabins=df_cabins.join(df_cabins_dummies)
df_cabins.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name     Sex  Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 6                             McCarthy, Mr. Timothy J    male   54      0
# 10                    Sandstrom, Miss. Marguerite Rut  female    4      1
# 11                           Bonnell, Miss. Elizabeth  female   58      0
#
#     Parch    Ticket     Fare   ...    Cabin_letter Cabin_number  A  B  C  D  \
# 1       0  PC 17599  71.2833   ...               C           85  0  0  1  0
# 3       0    113803  53.1000   ...               C          123  0  0  1  0
# 6       0     17463  51.8625   ...               E           46  0  0  0  0
# 10      1   PP 9549  16.7000   ...               G            6  0  0  0  0
# 11      0    113783  26.5500   ...               C          103  0  0  1  0
#
#     E  F  G  T
# 1   0  0  0  0
# 3   0  0  0  0
# 6   1  0  0  0
# 10  0  0  1  0
# 11  0  0  0  0
#
# [5 rows x 24 columns]

# %%
import statsmodels.api as sm

df_cabins=df_cabins.dropna(how='any')
print len(df_cabins)

x1 = df_cabins[['A','B', 'C', 'D', 'E', 'F', 'G', 'T']].values
y1 = df_cabins['Survived'].values

X1 = sm.add_constant(x1, prepend=True)
results = sm.OLS(y1, X1).fit()
results.summary()
# Out:
# 183
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.038
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.9823
# Date:                Mon, 10 Nov 2014   Prob (F-statistic):              0.446
# Time:                        21:32:27   Log-Likelihood:                -117.75
# No. Observations:                 183   AIC:                             251.5
# Df Residuals:                     175   BIC:                             277.2
# Df Model:                           7
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const          0.5030      0.065      7.766      0.000         0.375     0.631
# x1             0.0803      0.136      0.589      0.556        -0.189     0.349
# x2             0.2411      0.091      2.662      0.008         0.062     0.420
# x3             0.0852      0.087      0.979      0.329        -0.087     0.257
# x4             0.2389      0.099      2.418      0.017         0.044     0.434
# x5             0.2303      0.100      2.309      0.022         0.033     0.427
# x6             0.1333      0.141      0.946      0.346        -0.145     0.412
# x7            -0.0030      0.218     -0.014      0.989        -0.432     0.426
# x8            -0.5030      0.420     -1.197      0.233        -1.333     0.326
# ==============================================================================
# Omnibus:                      217.679   Durbin-Watson:                   1.978
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               29.760
# Skew:                          -0.726   Prob(JB):                     3.45e-07
# Kurtosis:                       1.660   Cond. No.                     1.91e+08
# ==============================================================================
#
# Warnings:
# [1] The smallest eigenvalue is 6.01e-15. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
cabin_names=list(pd.unique(df['Cabin'].values.ravel()))
print cabin_names.sort()
print cabin_names, len(cabin_names)

ticket_names=list(pd.unique(df['Ticket'].values.ravel()))
#print ticket_names.sort()
#print ticket_names

embarked_names=list(pd.unique(df['Embarked'].values.ravel()))
print embarked_names

# %% [markdown]
# I decided to replace missing values with ___ because ___
# Think statistically
#
# We have _ values in overall and ___ of them are Nan values. Thowing them away is not an option.
# I am going ot set the missing values to the mean values of similar items.
# Another motivation to use means is that the techniques we are going to use are ___
#
# Naive Bayes: the probabiliy of a feature given to a class

# %% [markdown]
# ###### 2. Create and run a logistic regression on the Titanic data to predict the survival of passengers.

# %% [markdown]
# ###### a. Make sure your model results are reproducible by the instructor team, given any random aspects to your code / steps.

# %% [markdown]
# Involve such constructions as create Table is exists etc
# Any directories

# %% [markdown]
# ###### b. Show your model output. Include coefficient values.

# %% [markdown]
# Output as an equation'
# Output as a python function

# %% [markdown]
# ###### c. Explain which features are predictive for this logistic regression and,
# intuitively, why you think this may be so. Describe your thinking / logic
# in words. It is not sufficient to cite output statistics.

# %% [markdown]
# explain the results/story telling/include nice visuals

# %% [markdown]
# ###### d. Make sure that you can push new data points through your model to get
# regression output. We will be providing a test set for this purpose.

# %% [markdown]
# test/train split + out of sample data (include room for it)

# %% [markdown]
# ###### 3. Implement cross-validation for your logistic regression. Pick the number of folds. Explain your choice.

# %%
The number of folds will depend on the cross validation score

# %% [markdown]
# ###### 4. Create an ROC curve for your logistic regression by varying the threshold value for survival.

# %% [markdown]
# The Confusion matrix can exist for more than two different states. But ROC curve looks nive because its tow dimentional

# %% [markdown]
# ###### a. Plot this ROC curve visually.

# %% [markdown]
# ROC curve is showing the sensitivity and specificity scores
# ROC: Receiver Operating Characteristic

# %% [markdown]
# ###### b. What is the AUC for your model?

# %% [markdown]
# what is the goal of the model? Which types of errors are accepted and which are not?

# %% [markdown]
# AUC - Area under curve

# %% [markdown]
# ###### c. Explain why the model has achieved this level of accuracy/precision.

# %% [markdown]
# hmmm

# %% [markdown]
# ###### d. Explain how you could improve these metrics, as potential next steps.

# %% [markdown]
# hmmm

# %% [markdown]
# ###### e. Armed with this knowledge, what threshold value would you use? Why?
# Describe your thinking.

# %% [markdown]
# hmm
