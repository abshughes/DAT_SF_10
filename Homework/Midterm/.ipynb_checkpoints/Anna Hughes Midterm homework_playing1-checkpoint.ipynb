# %% [markdown]
# ###### Importing data and packages

# %%
import pandas as pd
import numpy as np
import string
import statsmodels.api as sm
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
import string
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
from sklearn.cross_validation import train_test_split

# %matplotlib inline

df=pd.read_csv('train.csv')
df = df.drop(["Ticket", 'Cabin'], axis=1)

# %% [markdown]
# ###### Exloring the data graphically

# %%
df.groupby('Sex').Survived.count().plot(kind='bar', color='red')
df.groupby('Sex').Survived.sum().plot(kind='bar', color='blue')

# %%
df.groupby('Pclass').Survived.count().plot(kind='bar', color='red')
df.groupby('Pclass').Survived.sum().plot(kind='bar', color='blue')

# %%
df.groupby('Embarked').Survived.count().plot(kind='bar', color='red')
df.groupby('Embarked').Survived.sum().plot(kind='bar', color='blue')

# %% [markdown]
# ###### Here is a number of functions I am going to use for data cleaning and feature creation. They don't really work independently and require to be applied in certain order. But this is still better solution than to write the code all over again for a test sample.

# %%
# Function for creating the column 'Title' and filling it in with the word from 'Name' field
def title_fill(df) :
    for i in df.index: 
        df.ix[i, 'Title']=df.ix[i, 'Name'].partition('.')[0]
        df.ix[i, 'Title']=df.ix[i, 'Title'].partition(',')[2]
    return df

# Function for extracting all possible titles
def title_extract(df):
    title_names=list(pd.unique(df['Title']).ravel())
    return title_names

# Function for creating a new column 'Martial_status'
def title_replace(df):
    title_names_Mr=[' Don', ' Major', ' Capt', ' Jonkheer', ' Rev', ' Col', ' Mr', ' Sir']
    title_names_Mrs=[' the Countess', ' Mme', ' Mrs',' Lady', ' Dona']
    title_names_Miss=[' Mlle', ' Ms',' Miss']
    title_names_Master=[' Master']
    for i in df.index: 
        if df.ix[i, 'Title'] in title_names_Mr:
            df.ix[i, 'Title']='Mr'
            df.ix[i, 'Title_mar']=1
        elif df.ix[i, 'Title'] in title_names_Mrs:
            df.ix[i, 'Title']='Mrs'
            df.ix[i, 'Title_mar']=1
        elif df.ix[i, 'Title'] in title_names_Miss:
            df.ix[i, 'Title']='Miss'
            df.ix[i, 'Title_mar']=0
        elif df.ix[i, 'Title'] in title_names_Master:
            df.ix[i, 'Title'] = 'Master'
            df.ix[i, 'Title_mar']=0
        elif df.ix[i, 'Title']in [' Dr', 'Dr']:
            if df.ix[i, 'Sex']=='male':
                df.ix[i, 'Title']='Mr'
                df.ix[i, 'Title_mar']=1
            else:
                df.ix[i, 'Title']='Mrs'
                df.ix[i, 'Title_mar']=1
    return df

# Function for replacing Sex with 0/1, Embarked with 0/1/2, dropping Embarked NaN and replacing Fare from 0 to NaN
def other_replace(df):
    df['Sex_01']=df['Sex'].map({'female':1, 'male':0}).astype(int)
    df=df.dropna(subset=['Embarked'], how='any')
    df['Embarked_01']=df['Embarked'].map({'S':0, 'C':1, 'Q':2}).astype(int)
    df.Fare = df.Fare.map(lambda x: np.nan if x==0 else x)
    return df

# Function for imputing values into Age field
def age_matrix(df):
    median_ages = np.zeros((2, 2,3))
    for i in range(0,2):
        for j in range(0, 2):
            for k in range (0,3):
                median_ages[i, j,k] = df[(df['Sex_01'] == i) &(df['Title_mar'] == j) &(df['Pclass'] == k+1)]['Age'].dropna().median()
    return median_ages

def age_fill(df, median_ages):
    for i in range(0,2):     
        for j in range(0, 2):
            for k in range (0,3):
                df.loc[ (df.Age.isnull()) &(df['Sex_01'] == i)& (df['Title_mar'] == j) & (df['Pclass']== k+1),\
                    'Age'] = median_ages[i,j,k]
    return df

def fare_create(df):
    df['Family_Size']=df['SibSp']+df['Parch']+1
    df['Family_Size'].astype(int)
    df['Fare_pp']=df['Fare']/df['Family_Size']
    return df

def fare_matrix(df):
    df['Family_Size']=df['SibSp']+df['Parch']+1
    df['Family_Size'].astype(int)
    df['Fare_pp']=df['Fare']/df['Family_Size']
    average_fares = np.zeros((3,3))
    for j in range(0, 3):
        for k in range (0,3):
            average_fares[j,k] =df[(df['Embarked_01'] == j) &(df['Pclass'] == k+1)]['Fare_pp'].dropna().median()
    return average_fares

# Function for imputing values into Fare field
def fare_fill(df, average_fares):
    for j in range(0, 3):
        for k in range (0,3):
            df.loc[ (df.Fare_pp.isnull()) & (df['Embarked_01']== j) & (df['Pclass'] == k+1),'Fare_pp'] = average_fares[j,k]
    return df

# Function for creating a dummies tabel for Embarked
def embarked_dummies(df):
    df_dummies=pd.get_dummies(df['Embarked'])
    df=df.join(df_dummies)
    return df

# Function for creating a value 0/1 for Alone feature
def alone_fill(df):
    for i in df.index:
        if df.ix[i, 'Family_Size']==1:
            df.ix[i,'Alone']='1'
        else:
            df.ix[i,'Alone']='0'            
    return df

# Function for creating an Age_group (0 for Children, 1 for Adults)
def age_group_fill(df):
    for i in df.index:
        if df.ix[i, 'Age']<16:
            df.ix[i,'Age_group']='0'
        else:
            df.ix[i,'Age_group']='1'
    return df

# %%
df=title_fill(df)
tn=title_extract(df)
df=title_replace(df)
df=other_replace(df)

matrix_0=age_matrix(df)
df=age_fill(df, matrix_0)
df=fare_create(df)
matrix_1=fare_matrix(df)
df=fare_fill(df,matrix_1)

df=embarked_dummies(df)
df=alone_fill(df)
df=age_group_fill(df)

# %%
df.groupby('Alone').Survived.count().plot(kind='bar', color='red')
df.groupby('Alone').Survived.sum().plot(kind='bar', color='blue')

# %%
df.groupby('Age_group').Survived.count().plot(kind='bar', color='red')
df.groupby('Age_group').Survived.sum().plot(kind='bar', color='blue')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# 25            26         1       3
# 26            27         0       3
# 27            28         0       1
# 28            29         1       3
# 29            30         0       3
# ..           ...       ...     ...
# 861          862         0       2
# 862          863         1       1
# 863          864         0       3
# 864          865         0       2
# 865          866         1       2
# 866          867         1       2
# 867          868         0       1
# 868          869         0       3
# 869          870         1       3
# 870          871         0       3
# 871          872         1       1
# 872          873         0       1
# 873          874         0       3
# 874          875         1       2
# 875          876         1       3
# 876          877         0       3
# 877          878         0       3
# 878          879         0       3
# 879          880         1       1
# 880          881         1       2
# 881          882         0       3
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male   22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                               Heikkinen, Miss. Laina  female   26      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                             Allen, Mr. William Henry    male   35      0
# 5                                     Moran, Mr. James    male   26      0
# 6                              McCarthy, Mr. Timothy J    male   54      0
# 7                       Palsson, Master. Gosta Leonard    male    2      3
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female   27      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female   14      1
# 10                     Sandstrom, Miss. Marguerite Rut  female    4      1
# 11                            Bonnell, Miss. Elizabeth  female   58      0
# 12                      Saundercock, Mr. William Henry    male   20      0
# 13                         Andersson, Mr. Anders Johan    male   39      1
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female   14      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female   55      0
# 16                                Rice, Master. Eugene    male    2      4
# 17                        Williams, Mr. Charles Eugene    male   31      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female   31      1
# 19                             Masselmani, Mrs. Fatima  female   31      0
# 20                                Fynney, Mr. Joseph J    male   35      0
# 21                               Beesley, Mr. Lawrence    male   34      0
# 22                         McGowan, Miss. Anna "Annie"  female   15      0
# 23                        Sloper, Mr. William Thompson    male   28      0
# 24                       Palsson, Miss. Torborg Danira  female    8      3
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  
# 870      0    7.8958        S   ...            1       0            0
# 871      1   52.5542        S   ...            1       1            0
# 872      0    5.0000        S   ...            1       0            0
# 873      0    9.0000        S   ...            1       0            0
# 874      0   24.0000        C   ...            1       1            1
# 875      0    7.2250        C   ...            0       1            1
# 876      0    9.8458        S   ...            1       0            0
# 877      0    7.8958        S   ...            1       0            0
# 878      0    7.8958        S   ...            1       0            0
# 879      1   83.1583        C   ...            1       1            1
# 880      1   26.0000        S   ...            1       1            0
# 881      0    7.8958        S   ...            1       0            0
# 882      0   10.5167        S   ...            0       1            0
# 883      0   10.5000        S   ...            1       0            0
# 884      0    7.0500        S   ...            1       0            0
# 885      5   29.1250        Q   ...            1       1            2
# 886      0   13.0000        S   ...            1       0            0
# 887      0   30.0000        S   ...            0       1            0
# 888      2   23.4500        S   ...            0       1            0
# 889      0   30.0000        C   ...            1       0            1
# 890      0    7.7500        Q   ...            1       0            2
#
#      Family_Size    Fare_pp  C  Q  S  Alone Age_group
# 0              2   3.625000  0  0  1      0         1
# 1              2  35.641650  1  0  0      0         1
# 2              1   7.925000  0  0  1      1         1
# 3              2  26.550000  0  0  1      0         1
# 4              1   8.050000  0  0  1      1         1
# 5              1   8.458300  0  1  0      1         1
# 6              1  51.862500  0  0  1      1         1
# 7              5   4.215000  0  0  1      0         0
# 8              3   3.711100  0  0  1      0         1
# 9              2  15.035400  1  0  0      0         0
# 10             3   5.566667  0  0  1      0         0
# 11             1  26.550000  0  0  1      1         1
# 12             1   8.050000  0  0  1      1         1
# 13             7   4.467857  0  0  1      0         1
# 14             1   7.854200  0  0  1      1         0
# 15             1  16.000000  0  0  1      1         1
# 16             6   4.854167  0  1  0      0         0
# 17             1  13.000000  0  0  1      1         1
# 18             2   9.000000  0  0  1      0         1
# 19             1   7.225000  1  0  0      1         1
# 20             1  26.000000  0  0  1      1         1
# 21             1  13.000000  0  0  1      1         1
# 22             1   8.029200  0  1  0      1         0
# 23             1  35.500000  0  0  1      1         1
# 24             5   4.215000  0  0  1      0         0
# 25             7   4.483929  0  0  1      0         1
# 26             1   7.225000  1  0  0      1         1
# 27             6  43.833333  0  0  1      0         1
# 28             1   7.879200  0  1  0      1         1
# 29             1   7.895800  0  0  1      1         1
# ..           ...        ... .. .. ..    ...       ...
# 861            2   5.750000  0  0  1      0         1
# 862            1  25.929200  0  0  1      1         1
# 863           11   6.322727  0  0  1      0         1
# 864            1  13.000000  0  0  1      1         1
# 865            1  13.000000  0  0  1      1         1
# 866            2   6.929150  1  0  0      0         1
# 867            1  50.495800  0  0  1      1         1
# 868            1   9.500000  0  0  1      1         1
# 869            3   3.711100  0  0  1      0         0
# 870            1   7.895800  0  0  1      1         1
# 871            3  17.518067  0  0  1      0         1
# 872            1   5.000000  0  0  1      1         1
# 873            1   9.000000  0  0  1      1         1
# 874            2  12.000000  1  0  0      0         1
# 875            1   7.225000  1  0  0      1         0
# 876            1   9.845800  0  0  1      1         1
# 877            1   7.895800  0  0  1      1         1
# 878            1   7.895800  0  0  1      1         1
# 879            2  41.579150  1  0  0      0         1
# 880            2  13.000000  0  0  1      0         1
# 881            1   7.895800  0  0  1      1         1
# 882            1  10.516700  0  0  1      1         1
# 883            1  10.500000  0  0  1      1         1
# 884            1   7.050000  0  0  1      1         1
# 885            6   4.854167  0  1  0      0         1
# 886            1  13.000000  0  0  1      1         1
# 887            1  30.000000  0  0  1      1         1
# 888            4   5.862500  0  0  1      0         1
# 889            1  30.000000  1  0  0      1         1
# 890            1   7.750000  0  1  0      1         1
#
# [889 rows x 21 columns]

# %% [markdown]
# %matplotlib inline
# from pandas.tools.plotting import scatter_matrix
# scat = scatter_matrix(df, figsize = (20,20))

# %% [markdown]
# ###### Logistic regression

# %%
features = np.array(df[['Age', 'Pclass', 'Family_Size' ,'Title_mar','Fare_pp', 'Sex_01', 'C', 'S', 'Q']])
target = np.array(df['Survived'])
features_norm = (features - features.mean())/features.std()

# %% [markdown]
# I just used a cross validaton function

# %%
from sklearn.cross_validation import KFold

def cross_validate(X, y, classifier, k_fold) :

    # derive a set of (random) training and testing indices
    k_fold_indices = KFold(len(X), n_folds=k_fold,
                           shuffle=True, random_state=0)

    k_score_total = 0
    # for each training and testing slices run the classifier, and score the results
    for train_slice, test_slice in k_fold_indices :

        model = classifier(X[ train_slice  ],
                         y[ train_slice  ])
        k_score = model.score(X[ test_slice ],
                              y[ test_slice ])

        k_score_total += k_score

    # return the average accuracy
    return k_score_total/k_fold

# %%
model_lr = LogisticRegression(C=1).fit(features, target)

#cross_validate(features, target, model_lr, 10)

model_lr.coef_.ravel()
# Out:
# array([-0.03406273, -1.0645868 , -0.19396449, -0.24849905,  0.00261648,
#         2.50673154,  0.87689526,  0.4609285 ,  0.54230055])

# %% [markdown]
# ###### Equation output

# %%
train_feat, test_feat, train_target, test_target = train_test_split(features, target, train_size=0.6)
target_predicted_proba = model_lr.predict_proba(test_feat)

# %%
def plot_roc_curve(target_test, target_predicted_proba):
    fpr, tpr, thresholds = roc_curve(target_test, target_predicted_proba[:, 1])
    roc_auc = auc(fpr, tpr)
    
    # Plot ROC curve
    plt.plot(fpr, tpr, label='ROC curve (area = %0.3f)' % roc_auc)
    plt.plot([0, 1], [0, 1], 'k--')  # random predictions curve
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.0])
    plt.xlabel('False Positive Rate or (1 - Specifity)')
    plt.ylabel('True Positive Rate or (Sensitivity)')
    plt.title('Receiver Operating Characteristic')
    plt.legend(loc="lower right")
    
plot_roc_curve(test_target, target_predicted_proba)

# %% [markdown]
# Choosing a threshod value

# %% [markdown]
# ###### Importing the out of sample data (test.csv is this case)

# %%
dft=pd.read_csv('test.csv')

# %% [markdown]
# I am going to apply the same functions to clean and transform data for further input into

# %%
dft=title_fill(dft)
tnt=title_extract(dft)
tn=title_extract(df)
print tnt
# I just printed both to make sure I dont have to modify the function of replacing titles for a test dataset, and indeed -  I foulf a new one (' Dona')
# Out:
# [' Mr', ' Mrs', ' Miss', ' Master', ' Ms', ' Col', ' Rev', ' Dr', ' Dona']

# %%
dft=title_replace(dft)
dft=other_replace(dft)
dft=age_fill(dft, matrix_0)
dft=fare_create(dft)
dft=fare_fill(dft, matrix_1)
dft=embarked_dummies(dft)
dft=alone_fill(dft)
dft=age_group_fill(dft)

# %%
dft1 = dft[['Age', 'Pclass', 'Family_Size' ,'Title_mar','Fare_pp', 'Sex_01', 'C', 'S', 'Q']]
df_thres=0.6
#dft1['Survived']=model_lr.predict(dft1)
dft_prob=model_lr.predict_proba(dft1)
dft1['Survived_prob']=dft_prob[:,1]
for i in dft1.index:
    if dft1.ix[i, 'Survived_prob']>df_thres:
        dft1.ix[i, 'Survived']=1
    else:
        dft1.ix[i, 'Survived']='0'
dft1
dft2=dft[['PassengerId']].join(dft1[['Survived']])
dft2.to_csv('Anna_Hughes_model', index_label=False, index=False)
