# %% [markdown]
# ###### Importing data and packages

# %%
import pandas as pd
import numpy as np
import string
import statsmodels.api as sm
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression

# %matplotlib inline

df=pd.read_csv('train.csv')

# %% [markdown]
# ###### Extracting Titles from Names

# %%
for i in df.index: 
    df.ix[i, 'Title']=df.ix[i, 'Name'].partition('.')[0]
    df.ix[i, 'Title']=df.ix[i, 'Title'].partition(',')[2]
Title_names=list(pd.unique(df['Title'].values.ravel()))
print Title_names
# Out:
# [' Mr', ' Mrs', ' Miss', ' Master', ' Don', ' Rev', ' Dr', ' Mme', ' Ms', ' Major', ' Lady', ' Sir', ' Mlle', ' Col', ' Capt', ' the Countess', ' Jonkheer']

# %% [markdown]
# Replacing titles with codes
# 0 for male, 1 for female (Title_sex)
# 0 for unmarried, 1 for married (Title_age)
# There are 4 titles left Mr, Mrs, Miss and Master

# %%
for i in df.index: 
    if df.ix[i, 'Title'] in [' Don', ' Major', ' Capt', ' Jonkheer', ' Rev', ' Col', ' Mr', ' Sir', 'Mr']:
        df.ix[i, 'Title']='Mr'
        df.ix[i, 'Title_sex']=0
        df.ix[i, 'Title_age']=1
    elif df.ix[i, 'Title'] in [' the Countess', ' Mme', ' Mrs',' Lady', 'Mrs']:
        df.ix[i, 'Title']='Mrs'
        df.ix[i, 'Title_sex']=1
        df.ix[i, 'Title_age']=1
    elif df.ix[i, 'Title'] in [' Mlle', ' Ms',' Miss', 'Miss']:
        df.ix[i, 'Title']='Miss'
        df.ix[i, 'Title_sex']=1
        df.ix[i, 'Title_age']=0
    elif df.ix[i, 'Title'] in [' Master', 'Master']:
        df.ix[i, 'Title'] = 'Master'
        df.ix[i, 'Title_sex']=0
        df.ix[i, 'Title_age']=0
    elif df.ix[i, 'Title']in [' Dr', 'Dr']:
        if df.ix[i, 'Sex']=='male':
            df.ix[i, 'Title']='Mr'
            df.ix[i, 'Title_sex']=0
            df.ix[i, 'Title_age']=1
        else:
            df.ix[i, 'Title']='Mrs'
            df.ix[i, 'Title_sex']=1
            df.ix[i, 'Title_age']=1
            
Title_names=list(pd.unique(df['Title'].values.ravel()))
print Title_names
# Out:
# ['Mr', 'Mrs', 'Miss', 'Master']

# %% [markdown]
# Here I am going to replace Sex with a 0/1 value (0 male, 1 female)

# %%
df['Sex_01']=df['Sex'].map({'female':1, 'male':0}).astype(int)

# %% [markdown]
# Checking whether the initial Sex values corresponds to the one derived from Title

# %%
for i in df.index: 
    if df.ix[i,'Sex_01']<>df.ix[i,'Title_sex']:
        print df.ix[i,'Name']
# nothing is printed because all data is consistent

# %% [markdown]
# I will use 3 dimensions to calculate the average age for.
# 1. Sex (equal to title_sex)
# 2. Title_age
# 3. Cabin class

# %%
median_ages = np.zeros((2,2,3))
for i in range(0, 2):
    for j in range(0, 2):
        for k in range (0,3):
            median_ages[i,j,k] = df[(df['Title_sex'] == i) &(df['Title_age'] == j) &(df['Pclass'] == k+1)]['Age'].dropna().median()
median_ages[:,0,:]
# Out:
# array([[  4.,   1.,   4.],
#        [ 30.,  24.,  18.]])

# %%
for i in range(0, 2):
    for j in range(0, 2):
        for k in range (0,3):
            df.loc[ (df.Age.isnull()) & (df['Title_sex'] == i)&(df['Title_age'] == j) & (df.Pclass == k+1),\
                'Age'] = median_ages[i,j,k]

# %% [markdown]
# Dropping records with missing values for 'embarked'

# %%
df=df.dropna(subset=['Embarked'], how='any')

# %% [markdown]
# ###### Fare preliminary clean

# %%
df['Family_Size']=df['SibSp']+df['Parch']+1
df['Fare_pp']=df['Fare']/df['Family_Size']
df.Fare = df.Fare.map(lambda x: np.nan if x==0 else x)

# %% [markdown]
# ###### Cabins

# %% [markdown]
# I am going to explore the data about cabins (there are only around 200 entries for this data)
# Common sense is that that

# %%
cabin_names=list(pd.unique(df['Cabin'].values.ravel()))
df['Cabin']=df['Cabin'].astype(str)
# df.info()
# print cabin_names, len(cabin_names)

for i in df.index: 
    if df.ix[i, 'Cabin']<>'nan':
        df.ix[i, 'Deck']=df.ix[i, 'Cabin'][0]
    else:
        df.ix[i, 'Cabin']=np.nan
        df.ix[i, 'Deck']=np.nan
deck_names=list(pd.unique(df['Deck'].values.ravel()))
df_cabins=df.dropna(subset=['Deck'], how='any')
cabin_names=list(pd.unique(df['Deck'].values.ravel()))
print cabin_names
# Out:
# [nan, 'C', 'E', 'G', 'D', 'A', 'B', 'F', 'T']

# %%
df['Deck_01']=df['Deck'].map({'A':0, 'B':1,'C':2, 'D':3, 'E':4, 'F':5, 'G':6, 'T':7}).astype(float)
df['Embarked_01']=df['Embarked'].map({'S':0, 'C':1,'Q':2}).astype(int)

#median_ages = np.zeros((2,2,3))
#for i in range(0, 2):
#    for j in range(0, 2):
#        for k in range (0,3):
#            median_ages[i,j,k] = df[(df['Title_sex'] == i) &(df['Title_age'] == j) &(df['Pclass'] == k+1)]['Age'].dropna().median()
#median_ages[:,0,:]

# %%
average_fares1 = np.zeros((3,3))
for j in range(0, 3):
    for k in range (0,3):
        average_fares1[j,k] =df[(df['Embarked_01'] == j) &(df['Pclass'] == k+1)]['Fare'].dropna().median()
        print average_fares1[j,k]
average_fares1[:, :]
# Out:
# 52.5542
# 14.5
# 8.05
# 78.2667
# 24.0
# 7.8958
# 90.0
# 12.35
# 7.75
# array([[ 52.5542,  14.5   ,   8.05  ],
#        [ 78.2667,  24.    ,   7.8958],
#        [ 90.    ,  12.35  ,   7.75  ]])

# %% [markdown]
# Pclass is a good predictor for the Fare, port on embarkation - not really

# %%
average_fares2 = np.zeros(3)
for i in range(0, 3):
    average_fares2[i] =df[df['Pclass'] == i+1]['Fare'].dropna().median()
average_fares2
# Out:
# array([ 61.3792,  15.0229,   8.05  ])

# %%
for i in range(0, 3):
    df.loc[ (df.Fare.isnull()) & (df['Pclass'] == i+1),'Fare'] = average_fares2[i]

# %% [raw]
# %matplotlib inline
# from pandas.tools.plotting import scatter_matrix
# scat = scatter_matrix(df, figsize = (10,10))

# %% [markdown]
# ###### Doing PCA to get an inout into logistic regression

# %% [markdown]
# X=df[['Pclass', 'Sex_01', 'Age', 'SibSp', 'Parch','Fare' ]].values()
# y=df['Survived'].values()
# print y
# from sklearn.decomposition import PCA
# pca = PCA(n_components=10)
# X = pca.fit(X).transform(X)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# 25            26         1       3
# 26            27         0       3
# 27            28         0       1
# 28            29         1       3
# 29            30         0       3
# ..           ...       ...     ...
# 861          862         0       2
# 862          863         1       1
# 863          864         0       3
# 864          865         0       2
# 865          866         1       2
# 866          867         1       2
# 867          868         0       1
# 868          869         0       3
# 869          870         1       3
# 870          871         0       3
# 871          872         1       1
# 872          873         0       1
# 873          874         0       3
# 874          875         1       2
# 875          876         1       3
# 876          877         0       3
# 877          878         0       3
# 878          879         0       3
# 879          880         1       1
# 880          881         1       2
# 881          882         0       3
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male   22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                               Heikkinen, Miss. Laina  female   26      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                             Allen, Mr. William Henry    male   35      0
# 5                                     Moran, Mr. James    male   26      0
# 6                              McCarthy, Mr. Timothy J    male   54      0
# 7                       Palsson, Master. Gosta Leonard    male    2      3
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female   27      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female   14      1
# 10                     Sandstrom, Miss. Marguerite Rut  female    4      1
# 11                            Bonnell, Miss. Elizabeth  female   58      0
# 12                      Saundercock, Mr. William Henry    male   20      0
# 13                         Andersson, Mr. Anders Johan    male   39      1
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female   14      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female   55      0
# 16                                Rice, Master. Eugene    male    2      4
# 17                        Williams, Mr. Charles Eugene    male   31      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female   31      1
# 19                             Masselmani, Mrs. Fatima  female   31      0
# 20                                Fynney, Mr. Joseph J    male   35      0
# 21                               Beesley, Mr. Lawrence    male   34      0
# 22                         McGowan, Miss. Anna "Annie"  female   15      0
# 23                        Sloper, Mr. William Thompson    male   28      0
# 24                       Palsson, Miss. Torborg Danira  female    8      3
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female   38      1
# 26                             Emir, Mr. Farred Chehab    male   26      0
# 27                      Fortune, Mr. Charles Alexander    male   19      3
# 28                       O'Dwyer, Miss. Ellen "Nellie"  female   18      0
# 29                                 Todoroff, Mr. Lalio    male   26      0
# ..                                                 ...     ...  ...    ...
# 861                        Giles, Mr. Frederick Edward    male   21      1
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female   48      0
# 863                  Sage, Miss. Dorothy Edith "Dolly"  female   18      8
# 864                             Gill, Mr. John William    male   24      0
# 865                           Bystrom, Mrs. (Karolina)  female   42      0
# 866                       Duran y More, Miss. Asuncion  female   27      1
# 867               Roebling, Mr. Washington Augustus II    male   31      0
# 868                        van Melkebeke, Mr. Philemon    male   26      0
# 869                    Johnson, Master. Harold Theodor    male    4      1
# 870                                  Balkic, Mr. Cerin    male   26      0
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female   47      1
# 872                           Carlsson, Mr. Frans Olof    male   33      0
# 873                        Vander Cruyssen, Mr. Victor    male   47      0
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)  female   28      1
# 875                   Najib, Miss. Adele Kiamie "Jane"  female   15      0
# 876                      Gustafsson, Mr. Alfred Ossian    male   20      0
# 877                               Petroff, Mr. Nedelio    male   19      0
# 878                                 Laleff, Mr. Kristo    male   26      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female   56      0
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female   25      0
# 881                                 Markun, Mr. Johann    male   33      0
# 882                       Dahlberg, Miss. Gerda Ulrika  female   22      0
# 883                      Banfield, Mr. Frederick James    male   28      0
# 884                             Sutehall, Mr. Henry Jr    male   25      0
# 885               Rice, Mrs. William (Margaret Norton)  female   39      0
# 886                              Montvila, Rev. Juozas    male   27      0
# 887                       Graham, Miss. Margaret Edith  female   19      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   18      1
# 889                              Behr, Mr. Karl Howell    male   26      0
# 890                                Dooley, Mr. Patrick    male   32      0
#
#      Parch            Ticket      Fare    ...      Title Title_sex Title_age  \
# 0        0         A/5 21171    7.2500    ...         Mr         0         1
# 1        0          PC 17599   71.2833    ...        Mrs         1         1
# 2        0  STON/O2. 3101282    7.9250    ...       Miss         1         0
# 3        0            113803   53.1000    ...        Mrs         1         1
# 4        0            373450    8.0500    ...         Mr         0         1
# 5        0            330877    8.4583    ...         Mr         0         1
# 6        0             17463   51.8625    ...         Mr         0         1
# 7        1            349909   21.0750    ...     Master         0         0
# 8        2            347742   11.1333    ...        Mrs         1         1
# 9        0            237736   30.0708    ...        Mrs         1         1
# 10       1           PP 9549   16.7000    ...       Miss         1         0
# 11       0            113783   26.5500    ...       Miss         1         0
# 12       0         A/5. 2151    8.0500    ...         Mr         0         1
# 13       5            347082   31.2750    ...         Mr         0         1
# 14       0            350406    7.8542    ...       Miss         1         0
# 15       0            248706   16.0000    ...        Mrs         1         1
# 16       1            382652   29.1250    ...     Master         0         0
# 17       0            244373   13.0000    ...         Mr         0         1
# 18       0            345763   18.0000    ...        Mrs         1         1
# 19       0              2649    7.2250    ...        Mrs         1         1
# 20       0            239865   26.0000    ...         Mr         0         1
# 21       0            248698   13.0000    ...         Mr         0         1
# 22       0            330923    8.0292    ...       Miss         1         0
# 23       0            113788   35.5000    ...         Mr         0         1
# 24       1            349909   21.0750    ...       Miss         1         0
# 25       5            347077   31.3875    ...        Mrs         1         1
# 26       0              2631    7.2250    ...         Mr         0         1
# 27       2             19950  263.0000    ...         Mr         0         1
# 28       0            330959    7.8792    ...       Miss         1         0
# 29       0            349216    7.8958    ...         Mr         0         1
# ..     ...               ...       ...    ...        ...       ...       ...
# 861      0             28134   11.5000    ...         Mr         0         1
# 862      0             17466   25.9292    ...        Mrs         1         1
# 863      2          CA. 2343   69.5500    ...       Miss         1         0
# 864      0            233866   13.0000    ...         Mr         0         1
# 865      0            236852   13.0000    ...        Mrs         1         1
# 866      0     SC/PARIS 2149   13.8583    ...       Miss         1         0
# 867      0          PC 17590   50.4958    ...         Mr         0         1
# 868      0            345777    9.5000    ...         Mr         0         1
# 869      1            347742   11.1333    ...     Master         0         0
# 870      0            349248    7.8958    ...         Mr         0         1
# 871      1             11751   52.5542    ...        Mrs         1         1
# 872      0               695    5.0000    ...         Mr         0         1
# 873      0            345765    9.0000    ...         Mr         0         1
# 874      0         P/PP 3381   24.0000    ...        Mrs         1         1
# 875      0              2667    7.2250    ...       Miss         1         0
# 876      0              7534    9.8458    ...         Mr         0         1
# 877      0            349212    7.8958    ...         Mr         0         1
# 878      0            349217    7.8958    ...         Mr         0         1
# 879      1             11767   83.1583    ...        Mrs         1         1
# 880      1            230433   26.0000    ...        Mrs         1         1
# 881      0            349257    7.8958    ...         Mr         0         1
# 882      0              7552   10.5167    ...       Miss         1         0
# 883      0  C.A./SOTON 34068   10.5000    ...         Mr         0         1
# 884      0   SOTON/OQ 392076    7.0500    ...         Mr         0         1
# 885      5            382652   29.1250    ...        Mrs         1         1
# 886      0            211536   13.0000    ...         Mr         0         1
# 887      0            112053   30.0000    ...       Miss         1         0
# 888      2        W./C. 6607   23.4500    ...       Miss         1         0
# 889      0            111369   30.0000    ...         Mr         0         1
# 890      0            370376    7.7500    ...         Mr         0         1
#
#      Sex_01  Family_Size    Fare_pp  Deck  Deck_01 Embarked_01  Age_exp
# 0         0            2   3.625000   NaN      NaN           0     11.0
# 1         1            2  35.641650     C        2           1     19.0
# 2         1            1   7.925000   NaN      NaN           0     13.0
# 3         1            2  26.550000     C        2           0     17.5
# 4         0            1   8.050000   NaN      NaN           0     17.5
# 5         0            1   8.458300   NaN      NaN           2     13.0
# 6         0            1  51.862500     E        4           0     27.0
# 7         0            5   4.215000   NaN      NaN           0      1.0
# 8         1            3   3.711100   NaN      NaN           0     13.5
# 9         1            2  15.035400   NaN      NaN           1      7.0
# 10        1            3   5.566667     G        6           0      2.0
# 11        1            1  26.550000     C        2           0     29.0
# 12        0            1   8.050000   NaN      NaN           0     10.0
# 13        0            7   4.467857   NaN      NaN           0     19.5
# 14        1            1   7.854200   NaN      NaN           0      7.0
# 15        1            1  16.000000   NaN      NaN           0     27.5
# 16        0            6   4.854167   NaN      NaN           2      1.0
# 17        0            1  13.000000   NaN      NaN           0     15.5
# 18        1            2   9.000000   NaN      NaN           0     15.5
# 19        1            1   7.225000   NaN      NaN           1     15.5
# 20        0            1  26.000000   NaN      NaN           0     17.5
# 21        0            1  13.000000     D        3           0     17.0
# 22        1            1   8.029200   NaN      NaN           2      7.5
# 23        0            1  35.500000     A        0           0     14.0
# 24        1            5   4.215000   NaN      NaN           0      4.0
# 25        1            7   4.483929   NaN      NaN           0     19.0
# 26        0            1   7.225000   NaN      NaN           1     13.0
# 27        0            6  43.833333     C        2           0      9.5
# 28        1            1   7.879200   NaN      NaN           2      9.0
# 29        0            1   7.895800   NaN      NaN           0     13.0
# ..      ...          ...        ...   ...      ...         ...      ...
# 861       0            2   5.750000   NaN      NaN           0     10.5
# 862       1            1  25.929200     D        3           0     24.0
# 863       1           11   6.322727   NaN      NaN           0      9.0
# 864       0            1  13.000000   NaN      NaN           0     12.0
# 865       1            1  13.000000   NaN      NaN           0     21.0
# 866       1            2   6.929150   NaN      NaN           1     13.5
# 867       0            1  50.495800     A        0           0     15.5
# 868       0            1   9.500000   NaN      NaN           0     13.0
# 869       0            3   3.711100   NaN      NaN           0      2.0
# 870       0            1   7.895800   NaN      NaN           0     13.0
# 871       1            3  17.518067     D        3           0     23.5
# 872       0            1   5.000000     B        1           0     16.5
# 873       0            1   9.000000   NaN      NaN           0     23.5
# 874       1            2  12.000000   NaN      NaN           1     14.0
# 875       1            1   7.225000   NaN      NaN           1      7.5
# 876       0            1   9.845800   NaN      NaN           0     10.0
# 877       0            1   7.895800   NaN      NaN           0      9.5
# 878       0            1   7.895800   NaN      NaN           0     13.0
# 879       1            2  41.579150     C        2           1     28.0
# 880       1            2  13.000000   NaN      NaN           0     12.5
# 881       0            1   7.895800   NaN      NaN           0     16.5
# 882       1            1  10.516700   NaN      NaN           0     11.0
# 883       0            1  10.500000   NaN      NaN           0     14.0
# 884       0            1   7.050000   NaN      NaN           0     12.5
# 885       1            6   4.854167   NaN      NaN           2     19.5
# 886       0            1  13.000000   NaN      NaN           0     13.5
# 887       1            1  30.000000     B        1           0      9.5
# 888       1            4   5.862500   NaN      NaN           0      9.0
# 889       0            1  30.000000     C        2           1     13.0
# 890       0            1   7.750000   NaN      NaN           2     16.0
#
# [889 rows x 22 columns]

# %% [markdown]
# ###### Logistic regression

# %%
df['Age_exp']=df['Age'].map(lambda x: x/2)
features = np.array(df[['Age','Title_age', 'Pclass', 'Family_Size', 'Fare_pp', 'Sex_01', 'Parch', 'SibSp']])
target = np.array(df['Survived'])

# %% [markdown]
# I just used a cross validaton function

# %%
from sklearn.cross_validation import KFold

def cross_validate(X, y, classifier, k_fold) :

    # derive a set of (random) training and testing indices
    k_fold_indices = KFold(len(X), n_folds=k_fold,
                           shuffle=True, random_state=0)

    k_score_total = 0
    # for each training and testing slices run the classifier, and score the results
    for train_slice, test_slice in k_fold_indices :

        model = classifier(X[ train_slice  ],
                         y[ train_slice  ])
        k_score = model.score(X[ test_slice ],
                              y[ test_slice ])

        k_score_total += k_score

    # return the average accuracy
    return k_score_total/k_fold

# %%
model_lr = LogisticRegression(C=1).fit

cross_validate(features, target, model_lr, 5)
# Out:
# 0.7941661905668761

# %% [markdown]
# df_cabins_dummies=pd.get_dummies(df_cabins['Cabin_letter'])
# df_cabins=df_cabins.join(df_cabins_dummies)
# df_cabins.head()

# %% [markdown]
# I decided to replace missing values with ___ because ___
# Think statistically
#
# We have _ values in overall and ___ of them are Nan values. Thowing them away is not an option.
# I am going ot set the missing values to the mean values of similar items.
# Another motivation to use means is that the techniques we are going to use are ___
#
# Naive Bayes: the probabiliy of a feature given to a class

# %% [markdown]
# ###### 2. Create and run a logistic regression on the Titanic data to predict the survival of passengers.

# %% [markdown]
# ###### a. Make sure your model results are reproducible by the instructor team, given any random aspects to your code / steps.

# %% [markdown]
# Involve such constructions as create Table is exists etc
# Any directories

# %% [markdown]
# ###### b. Show your model output. Include coefficient values.

# %% [markdown]
# Output as an equation'
# Output as a python function

# %% [markdown]
# ###### c. Explain which features are predictive for this logistic regression and,
# intuitively, why you think this may be so. Describe your thinking / logic
# in words. It is not sufficient to cite output statistics.

# %% [markdown]
# explain the results/story telling/include nice visuals

# %% [markdown]
# ###### d. Make sure that you can push new data points through your model to get
# regression output. We will be providing a test set for this purpose.

# %% [markdown]
# test/train split + out of sample data (include room for it)

# %% [markdown]
# ###### 3. Implement cross-validation for your logistic regression. Pick the number of folds. Explain your choice.

# %%
The number of folds will depend on the cross validation score

# %% [markdown]
# ###### 4. Create an ROC curve for your logistic regression by varying the threshold value for survival.

# %% [markdown]
# The Confusion matrix can exist for more than two different states. But ROC curve looks nive because its tow dimentional

# %% [markdown]
# ###### a. Plot this ROC curve visually.

# %% [markdown]
# ROC curve is showing the sensitivity and specificity scores
# ROC: Receiver Operating Characteristic

# %% [markdown]
# ###### b. What is the AUC for your model?

# %% [markdown]
# what is the goal of the model? Which types of errors are accepted and which are not?

# %% [markdown]
# AUC - Area under curve

# %% [markdown]
# ###### c. Explain why the model has achieved this level of accuracy/precision.

# %% [markdown]
# hmmm

# %% [markdown]
# ###### d. Explain how you could improve these metrics, as potential next steps.

# %% [markdown]
# hmmm

# %% [markdown]
# ###### e. Armed with this knowledge, what threshold value would you use? Why?
# Describe your thinking.

# %% [markdown]
# hmm
