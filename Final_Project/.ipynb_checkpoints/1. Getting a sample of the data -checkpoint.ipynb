# %%
import pandas as pd
import numpy as np

# %%
# !gzip -k merged.csv

# %%
# !ls -lh
# Out:
# total 9748152
# -rw-r--r--@ 1 annabachurina  staff   128K 29 ноя 14:36 Anna_Hughes_comments.pdf
# -rw-------  1 annabachurina  staff   205K  3 дек 14:23 Getting GPS data.ipynb
# -rw-r--r--  1 annabachurina  staff   184M  3 дек 14:17 MASTER.csv
# -rw-------  1 annabachurina  staff    31K  3 дек 14:37 Prototype1.ipynb
# -rw-r-----@ 1 annabachurina  staff   830K  2 дек 18:13 airports.csv
# -rw-r--r--  1 annabachurina  staff    41K  2 дек 20:04 airports_GPS
# -rw-r--r--  1 annabachurina  staff    15M 24 ноя 20:50 data1.csv
# -rw-r--r--  1 annabachurina  staff   1,2M 24 ноя 20:50 data1.csv.gz
# -rw-r--r--  1 annabachurina  staff   3,8G  3 дек 14:32 merged.csv
# -rw-r--r--  1 annabachurina  staff   664M  3 дек 14:32 merged.csv.gz

# %%
#df=pd.read_csv('merged.csv', compression = 'gzip')
df=pd.read_csv('merged.csv')

# %%
df.head()

# %%
dfn = df[df['ORIGIN_AIRPORT_ID'] == 14771]
#dfm = df[df['UNIQUE_CARRIER'] == 'DL']
#dfm=dfm[dfm['ORIGIN_AIRPORT_ID'] == 11057]

# %%
dfm.head()
# Out:
#        YEAR MONTH DAY_OF_MONTH DAY_OF_WEEK     FL_DATE UNIQUE_CARRIER  \
# 67843  2012     4            1           7  2012-04-01             DL
# 67877  2012     4            1           7  2012-04-01             DL
# 67966  2012     4            1           7  2012-04-01             DL
# 67969  2012     4            1           7  2012-04-01             DL
# 68075  2012     4            1           7  2012-04-01             DL
#
#       TAIL_NUM FL_NUM ORIGIN_AIRPORT_ID ORIGIN_CITY_MARKET_ID  \
# 67843   N318US    521             11057                 31057
# 67877   N775NC    705             11057                 31057
# 67966   N786NC    823             11057                 31057
# 67969   N600TR    826             11057                 31057
# 68075   N961DL    944             11057                 31057
#
#                ...          AIR_TIME FLIGHTS DISTANCE DISTANCE_GROUP  \
# 67843          ...               215       1     1727              7
# ...

# %%
#dfn.to_csv('sfo.csv')
dfm.to_csv('dl521.csv')

# %%
import random
k=random.sample(dfm.index, 10000)
#print k
# k is going to be my final dataset
df1= dfm.ix[k]
df1.head()
# Out:
#           YEAR MONTH DAY_OF_MONTH DAY_OF_WEEK     FL_DATE UNIQUE_CARRIER  \
# 4252776   2013    12           15           7  2013-12-15             DL
# 1331290   2014     4           27           7  2014-04-27             DL
# 15287085  2013    11           26           2  2013-11-26             DL
# 14553467  2012    11            4           7  2012-11-04             DL
# 2906710   2014     8           13           3  2014-08-13             DL
#
#          TAIL_NUM FL_NUM ORIGIN_AIRPORT_ID ORIGIN_CITY_MARKET_ID  \
# 4252776    N915DN   2597             11057                 31057
# 1331290    N929DN    823             11057                 31057
# 15287085   N912DN   1328             11057                 31057
# 14553467   N355NB   1024             11057                 31057
# 2906710    N340NW    521             11057                 31057
#
#                   ...          AIR_TIME FLIGHTS DISTANCE DISTANCE_GROUP  \
# ...

# %%
df1.head()
# Out:
#           YEAR MONTH DAY_OF_MONTH DAY_OF_WEEK     FL_DATE UNIQUE_CARRIER  \
# 15743732  2012    10           11           4  2012-10-11             WN
# 3095901   2014     8           14           4  2014-08-14             OO
# 3338575   2011    12            5           1  2011-12-05             WN
# 6481140   2012     1           12           4  2012-01-12             UA
# 12955099  2013     5            7           2  2013-05-07             OO
#
#          TAIL_NUM FL_NUM ORIGIN_AIRPORT_ID ORIGIN_CITY_MARKET_ID  \
# 15743732   N387SW   2007             14771                 32457
# 3095901    N580SW   5323             14771                 32457
# 3338575    N606SW   2846             14771                 32457
# 6481140    N853UA    504             14771                 32457
# 12955099   N920SW   6404             14771                 32457
#
#                   ...          AIR_TIME FLIGHTS DISTANCE DISTANCE_GROUP  \
# ...

# %%
df1.to_csv('delta.csv')
